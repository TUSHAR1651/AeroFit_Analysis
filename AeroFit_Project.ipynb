# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv("data.csv")

df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
print("Dataset shape:", df.shape)
print("\nColumn names:")
print(df.columns)
print("\nData types of each column:")
print(df.dtypes)
print("\nFirst few rows of the dataset:")
print(df.head())
missing_values = df.isnull().sum()
missing_values
# Out:
# Dataset shape: (180, 9)
#
# Column names:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')
#
# Data types of each column:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object
#
# First few rows of the dataset:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47
# ...

# %% [markdown]
# There is no null value is present in the following data

# %%
frequency = [ 1, 31,  51, 55, 19, 4, 7, 9, 3]
IncomeIntervals = [(20000, 30000), (30000, 40000), (40000, 50000), (50000, 60000), (60000, 70000),
                    (70000, 80000), (80000, 90000), (90000, 100000), (100000, 110000)]

IncomeIntervals2 = [(50000,60000),(20000,30000), (30000,40000), (100000,110000), (40000,50000), (90000,100000),
               (80000,90000), (60000,70000), (70000,80000)]
frequency2 = [55 ,1, 31, 3, 51, 9, 7, 19 ,4]


plt.figure(figsize=(13, 6))
bars = plt.bar(range(len(IncomeIntervals)), frequency)
plt.xlabel('Income Intervals')
plt.ylabel('Frequency')
plt.title('Frequency within Income Intervals')
plt.xticks(range(0,9),[f"{i[0]}-{i[1]}" for i in IncomeIntervals])

for bar, count in zip(bars, frequency):
#     print(count)
#     print(bar.get_x)+bar.get_width()/2) 
    plt.text(bar.get_x()+bar.get_width()/2,bar.get_height(), count, ha='center')
plt.show()


plt.figure(figsize=(6, 7))
plt.pie(frequency2, labels=IncomeIntervals2, autopct='%1.1f%%')
plt.title('Pie Chart of Income Interval Frequencies')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation from the above Graph
#
# From the graph above, it is evident that individuals with a salary exceeding 30000 are more likely to purchase the product. However, the frequency of purchases decreases when the average salary exceeds 70000. Therefore, targeting individuals with salaries greater than 70000 may lead to an increase in sales, considering our product's higher price point. It appears that individuals with salaries lower than 30000 may be less inclined to purchase the product.
#
# ### Percentage of people according to the Different Income Intervals
# - 20000-30000 => 0.6%
# - 30000-40000 => 17.2%
# - 40000-50000 => 28.3%
# - 50000-60000 => 30.6%
# - 60000-70000 => 10.6%
# - 70000-80000 => 2.2%
# - 80000-90000 => 3.9%
# - 90000-100000 => 5.0%
# - 100000-110000 => 1.7%

# %%
valueCount = df['Product'].value_counts()
plt.figure(figsize=(3, 3))  
plt.ylabel("Frequency")
plt.xlabel("Different Products")
plt.title("Bar graph of frequency of people of different Product")
bars = plt.bar(valueCount.index, valueCount.values) 

for bar , count in zip(bars , valueCount.values):
    plt.text(bar.get_x() + bar.get_width()/2 , bar.get_height() , count , ha = 'center')

plt.figure(figsize=(5, 3))
plt.pie(valueCount, labels=valueCount.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Marital Status Frequencies')

plt.show()

# %% [markdown]
# ## Observation from the above Graph
#
# From the above Graph we can clearly see that Probability of person buying the KP281 is much higher than KP481 and KP781 as it is more budget friendly for the customers
#
# ### Percentage of people according to the Different Products
# - KP281 => 44.4%
# - KP481 => 33.3%
# - KP781 => 22.2%

# %%
plt.figure(figsize=(4, 4))
valueCount = df['MaritalStatus'].value_counts()
bars = plt.bar(valueCount.index, valueCount.values)
plt.xlabel('Marital Status')
plt.ylabel('Frequency')
plt.title('Bar Graph of Marital Status')
for bar , count in zip(bars , valueCount.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(),count, ha = 'center')
    
plt.show()


plt.figure(figsize=(5, 3))
plt.pie(valueCount, labels=valueCount.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Marital Status Frequencies')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Observation from the above Graph
#
# From here we can clearly see that Partnered people have a higher probability of buying the Product compared to the Single people
#
# ### Percentage of people according to MaritalStatus
# - Single => 40.6%
# - Partnered => 59.4%

# %%
plt.boxplot(df['Income'])
plt.title('Boxplot of Income')
plt.ylabel('Income')
plt.show()

# %% [markdown]
# ## Observation on the basis of the above Graph
#
# - Outliers are only on the upperbound
# - Median is nearly 50596.5

# %%
Q1Amount = df['Income'].quantile(0.25)
Q3Amount = df['Income'].quantile(0.75)
IQR = Q3Amount - Q1Amount

lowerBoundAmount = Q1Amount - 1.5 * IQR
upperBoundAmount = Q3Amount + 1.5 * IQR


outliersAmount = df[(df['Income'] < lowerBoundAmount) | (df['Income'] > upperBoundAmount)]
m = np.median(df['Income'])
print("Median =",m)
print("Lower Bound = ", lowerBoundAmount)
print("Upper Bound = ", upperBoundAmount)

print("Outliers on the basis of Amount")
outliersAmount
# Out:
# Median = 50596.5
# Lower Bound =  22144.875
# Upper Bound =  80581.875
# Outliers on the basis of Amount
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 159   KP781   27    Male         16     Partnered      4        5   83416
# 160   KP781   27    Male         18        Single      4        3   88396
# 161   KP781   27    Male         21     Partnered      4        4   90886
# 162   KP781   28  Female         18     Partnered      6        5   92131
# 164   KP781   28    Male         18        Single      6        5   88396
# 166   KP781   29    Male         14     Partnered      7        5   85906
# 167   KP781   30  Female         16     Partnered      6        5   90886
# 168   KP781   30    Male         18     Partnered      5        4  103336
# 169   KP781   30    Male         18     Partnered      5        5   99601
# 170   KP781   31    Male         16     Partnered      6        5   89641
# ...

# %% [markdown]
# Here I have founded outliers on the basis of the Income for that i have recoganised the lower and upper bound of the data and then stored all the values which are larger than upper bound and smaller than the lower bound

# %%
plt.boxplot(df['Age'])
plt.title('BoxPlot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Observation On the basis of the above graph
# - In this also outliers are only in the upperbound
# - In this the median is 26

# %%
Q1Age = df['Age'].quantile(0.25)
Q3Age = df['Age'].quantile(0.75)
IQRAge = Q3Age - Q1Age


lowerBoundAge = Q1Age - 1.5 * IQRAge
upperBoundAge = Q3Age + 1.5 * IQRAge


outliersAge = df[(df['Age'] < lowerBoundAge) | (df['Age'] > upperBoundAge)]

m = np.median(df['Age'])
print("Median =",m)
print("Lower Bound =", lowerBoundAge)
print("Upper Bound =", upperBoundAge)

print("Outliers on the basis of Age:")
outliersAge
# Out:
# Median = 26.0
# Lower Bound = 10.5
# Upper Bound = 46.5
# Outliers on the basis of Age:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 78    KP281   47    Male         16     Partnered      4        3   56850
# 79    KP281   50  Female         16     Partnered      3        3   64809
# 139   KP481   48    Male         16     Partnered      2        3   57987
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 78      94
# 79      66
# 139     64
# 178    120
# 179    180

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Product': ['KP281', 'KP481', 'KP781'],
        'Frequency': [80, 60, 40]}
dff = pd.DataFrame(data)

ProductAmounts = {
    'KP281': 1500,
    'KP481': 1750,
    'KP781': 2500,
}

dff['Amount Generated'] = dff['Frequency'] * dff['Product'].map(ProductAmounts)

plt.figure(figsize=(4, 5))
bars = plt.bar(dff['Product'], dff['Amount Generated'])

for bar, amount in zip(bars, dff['Amount Generated']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() ,amount, ha='center', va='bottom')

plt.xlabel('Product')
plt.ylabel('Amount Generated')
plt.title('Amount Generated by Products')
plt.show()


plt.figure(figsize=(4, 5))
plt.pie(dff['Amount Generated'], labels=dff['Product'], autopct='%1.1f%%', startangle=90)

plt.axis('equal') 
plt.title('Distribution of Amount Generated by Products')

plt.show()

# %% [markdown]
# ## Amounts generated by different Products
# - KP281 => 36.9%
# - KP481 => 32.3%
# - KP781 => 30.8%

# %%
plt.figure(figsize=(5, 5)) 
sns_plot = sns.countplot(x='Gender', hue='Product', data=df)


plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Countplot of Products Bought by Gender')

plt.tight_layout()
plt.show()


men_df = df[df['Gender'] == 'Male']
women_df = df[df['Gender'] == 'Female']

plt.figure(figsize=(4, 4))
men_product_counts = men_df['Product'].value_counts()
plt.pie(men_product_counts, labels=men_product_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Products Bought by Men')
plt.show()


plt.figure(figsize=(4, 4))
women_product_counts = women_df['Product'].value_counts()
plt.pie(women_product_counts, labels=women_product_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Products Bought by Women')
plt.show()

# %% [markdown]
# ## Obseravtions on the basis of above graph

# %%
plt.figure(figsize=(5, 6))
sns.countplot(x='Fitness', hue='Product', data=df)
plt.title('Countplot of Product Purchases by Fitness')
plt.xlabel('Fitness')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Observations on the basis of above graph
# - People with 1 fitness only buy very less products
# - People with 2 fitness bought nearly 15 KP281 and 12 KP481
# - People with 3 fitness bought the highest number of products mainly KP281 more than 50 and approximately 40 KP481 and 4 KP781 machines
# - People with 4 fitness bought all the 3 products nearly 9
# - People with 5 fitness bought mostly the KP781 approx 30 and 2 KP281 also
# From here we can conclude that people with more fitness parameter = 5 prefer only KP781 to buy

# %%
plt.figure(figsize=(6, 4))
value_counts_sorted = df['Fitness'].value_counts().sort_index()
plt.bar(value_counts_sorted.index, value_counts_sorted.values)
for x, y in zip(value_counts_sorted.index, value_counts_sorted.values):
    plt.text(x, y, str(y), ha='center')

plt.xlabel('Fitness')
plt.ylabel('Frequency')
plt.title('Bar Graph of Fitness')
plt.show()


plt.figure(figsize=(6, 3))
fitness_counts = df['Fitness'].value_counts()
plt.pie(fitness_counts, labels=fitness_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart of Fitness Frequencies')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Observation on the above graph
# - fitness   percentage of Customers
# -    1  =>  1.1%
# -    2  =>  14.4%
# -    3  =>  53.9%
# -    4  =>  13.3%
# -    5  =>  17.2%

# %%
high_distance_df = df[df['Miles'] > 180]

plt.figure(figsize=(5, 5))
sns.countplot(data=high_distance_df, x='Miles', hue='Product')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.title('Countplot of Distance greater than 180 with Product')
plt.show()

product_counts = high_distance_df['Product'].value_counts()
plt.figure(figsize=(3, 3))
plt.pie(product_counts, labels=product_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Products Bought for Distances greater than 180')
plt.show()

# %% [markdown]
# ## Observation from the above graph
# - From the above graph we can see that people with more distance more than 180 miles prefer to buy KP781 approximately 84.6 % and very few bought KP281 and KP481

# %%
high_income_df = df[df['Income'] > 67000]

plt.figure(figsize=(10, 6))
sns.countplot(data=high_income_df, x='Income', hue='Product')
plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Countplot of Incomes above $70,000 with Product Hue')
plt.xticks(rotation=30)
plt.show()

product_counts = high_income_df['Product'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(product_counts, labels=product_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Products Bought for Incomes greater than $70,000')
plt.show()

# %% [markdown]
# ## Observation from the Above Graph
# - 88.9% wants to buy the KP781
# - 3.7% wants to buy the KP481
# - 7.4% wants to buy the KP281

# %%
sns.histplot(df['Age'], kde=True, bins=10, color='blue', edgecolor='black')


plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age')

plt.show()

# %% [markdown]
# Here I have plooted the graph of the People of different age who prefer to buy the product
# From here we can conclude that mostly people who bought the product are in the range of 20 to 35 years of age

# %%
numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(16, 10))
sns.heatmap(numeric.corr(), annot=True, vmin=-1, vmax=1, cmap="coolwarm") 
plt.show()

# %% [markdown]
# ## Obseravtion of the above graph
# The above graph is gives the corelation between 2 quantities it clearly indicates that usage , Income and Usage ,Fitness and Usage, Miles and Usage , Fitness are having a very high corelation

# %%
sns.pairplot(df, hue='Product')
plt.show()

# %% [markdown]
# Here I have plotted the pairplot of every element with the other of different Products

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Age', y='Income', hue='Product')
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Boxplot of Product by Age and Income')

plt.show()

# %% [markdown]
# ## Observation on the basis of the above graph
# - upperLimit of Income of people buying of buying the KP781 in every age is much higher than buying KP281 and KP481
# - Also the people with more age does not prefer to buy KP781

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Age', y='Miles', hue='Product')
plt.xlabel('Age')
plt.ylabel('Miles')
plt.title('Boxplot of product by Age and Miles')

plt.show()

# %% [markdown]
# ## Observation Of the above Plot
#
# From the above Plot we can have an observation that people of the age between 21 and 35 are buying the product and range of the different Products are as
# - KP281 50 to 150 miles
# - KP481 50 to 200 miles
# - KP781 100 to 300 miles

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Fitness', y='Income', hue='Product')
plt.xlabel('Fitness')
plt.ylabel('Income')
plt.title('Boxplot of Product by Age and Income')

plt.show()

# %% [markdown]
# ## Obseravtion of the above Plot
#
# From the above Plot we can clearly see that People with lower fitness prefer to buy only KP281 and KP481 Treadmills and range of income is also not much just between 30000 to 70000 but as the fitness increases now the Income plays an important role in buying the product the people with income more than 60000 mostly prefer KP781 machines

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(data=df, x='Fitness', y='Miles', hue='Product')
plt.xlabel('Fitness')
plt.ylabel('Miles')
plt.title('Boxplot of Product by Age and Income')

plt.show()

# %%
frequency = pd.crosstab(index=df['Product'], columns=df['Age'], dropna=True)

probabilities = frequency / frequency.values.sum()

print("Probability of each combination of Product and Age:")
probabilities
# Out:
# Probability of each combination of Product and Age:
# Age            18        19        20        21        22        23        24  \
# Product
# KP281    0.005556  0.016667  0.011111  0.022222  0.022222  0.044444  0.027778
# KP481    0.000000  0.005556  0.016667  0.016667  0.000000  0.038889  0.016667
# KP781    0.000000  0.000000  0.000000  0.000000  0.016667  0.016667  0.022222
#
# Age            25        26        27  ...        40        41        42  \
# Product                                ...
# KP281    0.038889  0.038889  0.016667  ...  0.005556  0.005556  0.000000
# KP481    0.061111  0.016667  0.005556  ...  0.016667  0.000000  0.000000
# KP781    0.038889  0.011111  0.016667  ...  0.005556  0.000000  0.005556
#
# Age            43        44        45        46        47        48        50
# Product
# KP281    0.005556  0.005556  0.000000  0.005556  0.005556  0.000000  0.005556
# KP481    0.000000  0.000000  0.005556  0.000000  0.000000  0.005556  0.000000
# ...

# %%
frequency = pd.crosstab(index=df['Product'], columns=df['Education'], dropna=True)

probabilities = frequency / frequency.values.sum()

print("Probability of each combination of Product and Education:")
probabilities
# Out:
# Probability of each combination of Product and Education:
# Education        12        13        14        15        16        18  \
# Product
# KP281      0.011111  0.016667  0.166667  0.022222  0.216667  0.011111
# KP481      0.005556  0.011111  0.127778  0.005556  0.172222  0.011111
# KP781      0.000000  0.000000  0.011111  0.000000  0.083333  0.105556
#
# Education        20        21
# Product
# KP281      0.000000  0.000000
# KP481      0.000000  0.000000
# KP781      0.005556  0.016667

# %% [markdown]
# ## Observation Of the Above PLot
#
# People with less Fitness Prefer to buy the KP281 and KP481 machines mostaly and people with higher Fitness prefer to buy KP781 and we can see that number of Miles walked also plays an important role in it People with higher fitness and also the people with Higher miles have an higher fitness and mostly prefer to buy the KP781 product
# the range of people with less fitness is very low and also they only prefer the KP281 and KP481 machines

# %%
df[df['Product'] == 'KP281'].describe().round(2)
# Out:
#          Age  Education  Usage  Fitness    Income   Miles
# count  80.00      80.00  80.00    80.00     80.00   80.00
# mean   28.55      15.04   3.09     2.96  46418.02   82.79
# std     7.22       1.22   0.78     0.66   9075.78   28.87
# min    18.00      12.00   2.00     1.00  29562.00   38.00
# 25%    23.00      14.00   3.00     3.00  38658.00   66.00
# 50%    26.00      16.00   3.00     3.00  46617.00   85.00
# 75%    33.00      16.00   4.00     3.00  53439.00   94.00
# max    50.00      18.00   5.00     5.00  68220.00  188.00

# %%
df[df['Product'] == 'KP481'].describe().round(2)
# Out:
#          Age  Education  Usage  Fitness    Income   Miles
# count  60.00      60.00  60.00    60.00     60.00   60.00
# mean   28.90      15.12   3.07     2.90  48973.65   87.93
# std     6.65       1.22   0.80     0.63   8653.99   33.26
# min    19.00      12.00   2.00     1.00  31836.00   21.00
# 25%    24.00      14.00   3.00     3.00  44911.50   64.00
# 50%    26.00      16.00   3.00     3.00  49459.50   85.00
# 75%    33.25      16.00   3.25     3.00  53439.00  106.00
# max    48.00      18.00   5.00     4.00  67083.00  212.00

# %%
df[df['Product'] == 'KP781'].describe().round(2)
# Out:
#          Age  Education  Usage  Fitness     Income   Miles
# count  40.00      40.00  40.00    40.00      40.00   40.00
# mean   29.10      17.32   4.78     4.62   75441.58  166.90
# std     6.97       1.64   0.95     0.67   18505.84   60.07
# min    22.00      14.00   3.00     3.00   48556.00   80.00
# 25%    24.75      16.00   4.00     4.00   58204.75  120.00
# 50%    27.00      18.00   5.00     5.00   76568.50  160.00
# 75%    30.25      18.00   5.00     5.00   90886.00  200.00
# max    48.00      21.00   7.00     5.00  104581.00  360.00

# %% [markdown]
# ## Recommendations for the company
# - As seen above most of the KP781 product is mostly bought by the males so company can reduce their profit of KP781 and cna sell the KP781 product at a lower prize to women customers
# - To encourage more customers to buy the KP281 and KP481 Treadmills, offer them at a good price. Also, let customers pay in installments over a few months to make it easier for them to afford. Make sure the treadmills are easy to use and work well with the app.
# - Company can also get some tech-support by building some app or website wfich on the basis of progress would give some points there may be learderboard and can give small prizes to weekly winners
# - Revenue genrated by all the products are almost same despite the huge difference in prizes company cna focus on increasing the revenue of KP781 by giving regular discounts in it by jusr giving 25% of their profit.
